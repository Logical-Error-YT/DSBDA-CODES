# %% [markdown]
# # Data Wrangling I
#
# This notebook demonstrates data wrangling using the **Titanic dataset** from a public URL.
#
# **Dataset Source:** https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
#
# **Description:** The Titanic dataset contains information about 891 passengers aboard the Titanic, including features like age, sex, ticket class, fare, and survival status.

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

print('All libraries imported successfully!')

# %% [markdown]
# ## Step 2: Load the Dataset
#
# We load the Titanic dataset directly from a public GitHub URL using `pd.read_csv()`.

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
print('Dataset loaded successfully!')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## Step 3: Data Preprocessing
#
# - `isnull().sum()` counts missing values per column.
# - `describe()` gives statistical summary of numeric columns.
# - `info()` shows data types and non-null counts.

# %%
print('=== Missing Values ===')
print(df.isnull().sum())

# %%
print('=== Statistical Summary ===')
df.describe()

# %%
print('=== Dataset Info ===')
df.info()

# %%
print('=== Dimensions ===')
print(f'Rows: {df.shape[0]}, Columns: {df.shape[1]}')

# %% [markdown]
# ## Step 4: Data Formatting and Normalization
#
# We check each column's data type and fix incorrect types if any.
# - `Age` and `Fare` are numeric — we will normalize them using MinMaxScaler.
# - `Survived` and `Pclass` are integers, which is correct.

# %%
print('=== Data Types ===')
print(df.dtypes)

# %%
# Fill missing Age with median, Embarked with mode
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop(columns=['Cabin'], inplace=True)  # Too many missing values

# Normalize Age and Fare using MinMaxScaler (scales to 0-1 range)
scaler = MinMaxScaler()
df[['Age_norm', 'Fare_norm']] = scaler.fit_transform(df[['Age', 'Fare']])
print('Missing values after cleaning:')
print(df.isnull().sum())
df[['Age', 'Age_norm', 'Fare', 'Fare_norm']].head()

# %% [markdown]
# ## Step 5: Convert Categorical Variables to Quantitative
#
# Columns like `Sex` and `Embarked` are categorical (text). We use `LabelEncoder` to convert them to numeric values so they can be used in ML models.

# %%
le = LabelEncoder()
df['Sex_encoded'] = le.fit_transform(df['Sex'])        # male=1, female=0
df['Embarked_encoded'] = le.fit_transform(df['Embarked'])  # C=0, Q=1, S=2

print('Encoding done!')
df[['Sex', 'Sex_encoded', 'Embarked', 'Embarked_encoded']].head(10)
